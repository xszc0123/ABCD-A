# %% [markdown]
# <a href="https://colab.research.google.com/github/xszc0123/ABCD-A/blob/20250328/0328.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
삼성전자 = 50000
주식_수 = 10
총평가금액 = 삼성전자 * 주식_수
print("총 평가금액:", 총평가금액, "원")
# Out:
# 총 평가금액: 500000 원

# %%
시가총액 = 298000000000000
현재가 = 50000
PER = 15.79

print("시가총액:", 시가총액, "원")
print("현재가:", 현재가, "원")
print("PER", PER)
# Out:
# 시가총액: 298000000000000 원
# 현재가: 50000 원
# PER 15.79

# %%
s = 'hello!'
t = 'python'
print(s, t, sep = ' ')
# Out:
# hello! python

# %%
a = 2
b = 3
print( a + a * b)
# Out:
# 8
