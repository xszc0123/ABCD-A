# %% [markdown]
# <a href="https://colab.research.google.com/github/xszc0123/ABCD-A/blob/20250310/%ED%8C%8C%EC%9D%B4%EC%8D%AC300.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#화면에 Hello World 문자열을 출력하시오.
print("Hello World")
# Out:
# Hello World

# %%
#화면에 Marry's cosmetics를 출력하시오.
print("Marry's cosmetics")
# Out:
# Marry's cosmetics

# %%
#화면에 신씨가 솔리질렀다. "도둑이야"를 출력하시오.
print('신씨가 소리질렀다. "도둑이야."')
# Out:
# 신씨가 소리질렀다. "도둑이야."

# %%
#화면에 "C:\windows"를 출력하시오.
print('"C:\windows"')
# Out:
# "C:\windows"

# %%
#코드를 실행하고 \t와 \n의 역할을 설명하시오.
print("안녕하세요. \n 만나서 \t\t 반갑습니다.")
# Out:
# 안녕하세요.
#  만나서 		 반갑습니다.

# %%
#print 여러 데이터 출력
print("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
#print()함수를 이용하여 never:kakao;sk;samsung를 출력하시오.
print("never", "kakao", "sk", "samsung", sep=';')
# Out:
# never;kakao;sk;samsung

# %%
#print()함수를 이용하여 never:kakao;sk;samsung를 출력하시오.
print("never", "kakao", "sk", "samsung", sep='/')
# Out:
# never/kakao/sk/samsung

# %%
#줄바꿈 없이 출력하시오.
print("first", end="");print("second")
# Out:
# firstsecond

# %%
#5/3의 결과를 화면에 출력하시오
print(5/3)
# Out:
# 1.6666666666666667
